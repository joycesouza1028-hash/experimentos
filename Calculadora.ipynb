# %% [markdown]
# <a href="https://colab.research.google.com/github/joycesouza1028-hash/experimentos/blob/main/Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = float(input("Digite um número: "))
numero2 = float(input("Digite um número: "))

print("Escolha a operação: ")
print("1 - Soma")
print("2 - Subtração")
print("3 - Multiplicação")
print("4 - Divisão")

operacao = input("Digite o numero da operação desejada:")

if operacao == "1":
  resultado = numero1 + numero2
  print(f"O resultado da soma é: {resultado}")
elif operacao == "2":
  resultado = numero1 - numero2
  print(f"O resultado da subtração é: {resultado}")
elif operacao == "3":
  resultado = numero1 * numero2
  print(f"O resultado da multiplicação é: {resultado}")
elif operacao == "4":
  resultado = nunero1 / numero2
  print(f"O resultado da divisão é: {resultado}")
# Out:
# Digite um número: 2
# Digite um número: 2
# Escolha a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# Digite o numero da operação desejada:3
# O resultado da multiplicação é: 4.0
