# %% [markdown]
# <a href="https://colab.research.google.com/github/joycesouza1028-hash/experimentos/blob/main/caixaTeste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#caixa de supermecado

produto = []

while True:
  nome = input("Produto: ")

  if nome.lower() == "fim":
    break

  quantidade = int(input("Quantidade: "))
  preco = float(input("Preço unitário: "))

  produto.append({
      "nome": nome,
      "quantidade": quantidade,
      "preco": preco
  })

subtotal = 0
for produto in produto:
  subtotal += produto["quantidade"] * produto["preco"]

print(f"Subtotal: R${subtotal:.2f}")

desconto = float(input("Desconto (%): "))

total = subtotal * (1 - desconto / 100)

print(f"Total a pagar: R${total:.2f}")

print("Obrigado pela compra!")
# Out:
# Produto: Arroz
# Quantidade: 2
# Preço unitário: 24
# Produto: feijao
# Quantidade: 2
# Preço unitário: 9
# Produto: limpa piso
# Quantidade: 1
# Preço unitário: 10
# Produto: fim
# Subtotal: R$76.00
# Desconto (%): 10
# Total a pagar: R$68.40
# Obrigado pela compra!
